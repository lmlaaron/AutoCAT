# %%
import json
 
# Opening JSON file
f = open('/home/geunbae/ray_results/PPO_cache_guessing_game_env_fix_2022-03-28_14-15-32nnmpib0o/result.json')
 
# returns JSON object as
# a dictionary

reward_mean = []

for x in range(1000):# check the total number 
    data=f.readline()
    data=json.loads(data)
    #print(data['perf'])
    #print(data['episode_reward_mean']) 
    #print(data['episode_reward_mean'])
    
    reward_mean.append(data['episode_reward_mean'])

#data = json.load(f)
 
# Closing file
f.close()
print(reward_mean)
# Out:
# [-8634.457671957673, -7690.9010600706715, -6976.970954356846, -6801.247401247401, -6009.142212189617, -5569.009216589861, -5653.164556962025, -5744.859813084112, -5587.468982630273, -5385.581395348837, -5417.516629711752, -5734.905660377359, -5599.633251833741, -5591.133004926109, -5250.800915331808, -6027.539503386004, -5347.8448275862065, -5068.076109936575, -5135.607675906183, -5324.137931034483, -5640.856481481482, -5543.341404358353, -5605.72429906542, -5538.403990024937, -5543.506493506494, -5061.141304347826, -5252.717391304348, -5705.026455026455, -5756.0109289617485, -5774.444444444444, -5280.736543909348, -5992.03125, -5363.548387096775, -5724.921135646688, -5549.2163009404385, -5283.976261127596, -4878.6377708978325, -5244.512195121952, -5934.735202492212, -5221.11801242236, -5503.9936102236425, -5705.825242718447, -5687.898089171975, -5834.803921568628, -5757.065217391304, -5844.19014084507, -5736.267605633803, -5353.934426229508, -5116.551724137931, -5075.496688741722, -
# ...

# %%
print(data)
# Out:
# {'episode_reward_max': 150.0, 'episode_reward_min': -11250.0, 'episode_reward_mean': -8634.457671957673, 'episode_len_mean': 5.26058201058201, 'episode_media': {}, 'episodes_this_iter': 756, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-10000.0, -10750.0, -10000.0, -10600.0, -10000.0, -10600.0, -10000.0, -11100.0, -10200.0, -10000.0, -10050.0, -10000.0, -10950.0, -10250.0, -150.0, -10000.0, -10000.0, -100.0, -10800.0, -10500.0, -10350.0, -10050.0, -10050.0, -10250.0, -10000.0, -10100.0, -350.0, -10000.0, -10150.0, -10150.0, -10100.0, -10300.0, -50.0, -10050.0, -10000.0, -10050.0, -10200.0, -10050.0, -10050.0, -10200.0, -10050.0, -10050.0, -10100.0, -10050.0, 100.0, -10100.0, -10000.0, -10100.0, -200.0, -10100.0, -10150.0, -700.0, -10050.0, -11200.0, -10350.0, -10050.0, -10050.0, -10550.0, -10000.0, -10000.0, -10050.0, -10000.0, -10250.0, -250.0, -10050.0, 50.0, -10000.0, -10100.0, -10300.0, -10450.
# ...

# %%
print(data['episode_reward_mean'])
# Out:
# -8634.457671957673

# %%
print(data['episode_reward_mean'])
# Out:
# 5.26058201058201
