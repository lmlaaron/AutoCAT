# %%
from ray.rllib.agents.ppo import PPOTrainer
from ray.rllib.agents.ppo.ppo_tf_policy import PPOTFPolicy

# %%
from ray.rllib.agents.ppo.ppo_torch_policy import PPOTorchPolicy
from ray.rllib.agents.a3c.a3c_torch_policy import A3CTorchPolicy
from ray.rllib.agents.a3c.a2c import A2CTrainer

# %%
import gym
from typing import Optional, Dict

import ray
from ray.rllib.agents.ppo.ppo_torch_policy import ValueNetworkMixin
from ray.rllib.evaluation.episode import MultiAgentEpisode
from ray.rllib.evaluation.postprocessing import compute_gae_for_sample_batch, \
    Postprocessing
from ray.rllib.models.action_dist import ActionDistribution
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.policy.policy import Policy
from ray.rllib.policy.policy_template import build_policy_class
from ray.rllib.policy.sample_batch import SampleBatch
from ray.rllib.utils.annotations import Deprecated
from ray.rllib.utils.framework import try_import_torch
from ray.rllib.utils.torch_ops import apply_grad_clipping, sequence_mask
from ray.rllib.utils.typing import TrainerConfigDict, TensorType, \
    PolicyID, LocalOptimizer

torch, nn = try_import_torch()

# %%
def after_init(policy: Policy, obs_space: gym.spaces.Space, 
              action_space: gym.spaces.Space, config: TrainerConfigDict)->None:
        policy.past_len = 5        
        policy.past_models = deque(maxlen =policy.past_len)
        policy.timestep = 0

# %%
def compute_div_loss(policy: Policy, model: ModelV2,
                      dist_class: ActionDistribution,
                      train_batch: SampleBatch):
    logits, _ = model.from_batch(train_batch)
    values = model.value_function()
    valid_mask = torch.ones_like(values, dtype=torch.bool)
    dist = dist_class(logits, model)
    log_probs = dist.logp(train_batch[SampleBatch.ACTIONS]).reshape(-1)
    
    divs = []
    for idx, past_model in enumerate(policy.past_models):
        logits, _ = past_model.from_batch(train_batch)
        values = past_model.value_function()
        valid_mask = torch.ones_like(values, dtype=torch.bool)
        dist = dist_class(logits, past_model)
        past_log_probs = dist.logp(train_batch[SampleBatch.ACTIONS]).reshape(-1) 
        div = div_metric(log_probs, past_log_probs).sum(1)
        div = div.mean(0)
        divs.append(div)
    
    divs_sort_idx = np.argsort([d.data[0] for d in divs])
    div_loss_orig = 0
    for idx in divs_sort_idx:
        div_loss += divs[idx]
        div_loss_orig += divs[idx]
    
    div_loss = div_loss / self.past_len
    
    return div_loss

# %%
def actor_critic_loss(policy: Policy, model: ModelV2,
                      dist_class: ActionDistribution,
                      train_batch: SampleBatch) -> TensorType:
    logits, _ = model.from_batch(train_batch)
    values = model.value_function()
    policy.timestep += 1
    
    if policy.timestep % 100 == 0:
        policy.past_models.append(copy.deepcopy(model))
    
    if policy.is_recurrent():
        B = len(train_batch[SampleBatch.SEQ_LENS])
        max_seq_len = logits.shape[0] // B
        mask_orig = sequence_mask(train_batch[SampleBatch.SEQ_LENS],
                                  max_seq_len)
        valid_mask = torch.reshape(mask_orig, [-1])
    else:
        valid_mask = torch.ones_like(values, dtype=torch.bool)

    dist = dist_class(logits, model)
    log_probs = dist.logp(train_batch[SampleBatch.ACTIONS]).reshape(-1)
    pi_err = -torch.sum(
        torch.masked_select(log_probs * train_batch[Postprocessing.ADVANTAGES],
                            valid_mask))

    # Compute a value function loss.
    if policy.config["use_critic"]:
        value_err = 0.5 * torch.sum(
            torch.pow(
                torch.masked_select(
                    values.reshape(-1) -
                    train_batch[Postprocessing.VALUE_TARGETS], valid_mask),
                2.0))
    # Ignore the value function.
    else:
        value_err = 0.0

    entropy = torch.sum(torch.masked_select(dist.entropy(), valid_mask))


    total_loss = (pi_err + value_err * policy.config["vf_loss_coeff"] -
                  entropy * policy.config["entropy_coeff"] - compute_div_loss(policy, model, dist_class, train_batch))

    policy.entropy = entropy
    policy.pi_err = pi_err
    policy.value_err = value_err

    return total_loss

# %%
CustomPolicy = A3CTorchPolicy.with_updates(
    name="MyCustomA3CTorchPolicy",
    loss_fn=actor_critic_loss,
    after_init=after_init)
CustomTrainer = A2CTrainer.with_updates(
    default_policy=CustomPolicy)

# %%
tune.run(CustomTrainer, config={"env": 'Frostbite-v0', "num_gpus":1})
# Out:
# == Status ==<br>Memory usage on this node: 4.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=2409) 2021-12-19 15:15:51,512	INFO trainer.py:741 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=2409) 2021-12-19 15:15:51,512	INFO trainer.py:758 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# == Status ==<br>Memory usage on this node: 5.0/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=2409) 2021-12-19 15:15:59,553	WARNING trainer_template.py:185 -- `execution_plan` functions should accept `trainer`, `workers`, and `config` as args!
# (pid=2409) 2021-12-19 15:15:59,554	WARNING util.py:57 -- Install gputil for GPU system monitoring.
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 200
#   custom_metrics: {}
#   date: 2021-12-19_15-16-05
#   done: false
#   episode_len_mean: .nan
#   episode_media: {}
#   episode_reward_max: .nan
#   episode_reward_mean: .nan
#   episode_reward_min: .nan
#   episodes_this_iter: 0
#   episodes_total: 0
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 39.999996185302734
#           model: {}
#           policy_entropy: 106.24060821533203
#           policy_loss: 2.371837854385376
#           var_gnorm: 10.8916597366333
#           vf_explained_var: -0.013216972351074219
#           vf_loss: 0.17337457835674286
#         train: null
#     num_agent_steps_sampled: 200
#     num_agent_steps_trained: 200
#     num_steps_sampled: 200
#     num_steps_trained: 200
#   iterations_since_restore: 1
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 19.4
#     ram_util_percent: 39.559999999999995
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf: {}
#   time_since_restore: 6.340800523757935
#   time_this_iter_s: 6.340800523757935
#   time_total_s: 6.340800523757935
#   timers:
#     learn_throughput: 33.346
#     learn_time_ms: 5997.773
#     load_throughput: 5680.452
#     load_time_ms: 35.208
#     sample_throughput: 660.744
#     sample_time_ms: 302.689
#     update_time_ms: 3.588
#   timestamp: 1639944965
#   timesteps_since_restore: 0
#   timesteps_total: 200
#   training_iteration: 1
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     1</td><td style="text-align: right;">          6.3408</td><td style="text-align: right;"> 200</td><td style="text-align: right;">     nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">               nan</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     1</td><td style="text-align: right;">          6.3408</td><td style="text-align: right;"> 200</td><td style="text-align: right;">     nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">               nan</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 7600
#   custom_metrics: {}
#   date: 2021-12-19_15-16-15
#   done: false
#   episode_len_mean: 418.55555555555554
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 77.77777777777777
#   episode_reward_min: 60.0
#   episodes_this_iter: 18
#   episodes_total: 18
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 5.307250943232094e-26
#           policy_loss: 0.0
#           var_gnorm: 10.904439926147461
#           vf_explained_var: 0.8947932720184326
#           vf_loss: 9.513306617736816
#         train: null
#     num_agent_steps_sampled: 7600
#     num_agent_steps_trained: 7600
#     num_steps_sampled: 7600
#     num_steps_trained: 7600
#   iterations_since_restore: 2
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 30.87142857142857
#     ram_util_percent: 40.092857142857156
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05424734605860942
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7371973345324228
#     mean_inference_ms: 1.3402484963047476
#     mean_raw_obs_processing_ms: 0.19305842514258878
#   time_since_restore: 16.347381114959717
#   time_this_iter_s: 10.006580591201782
#   time_total_s: 16.347381114959717
#   timers:
#     learn_throughput: 14168.462
#     learn_time_ms: 14.116
#     load_throughput: 249683.246
#     load_time_ms: 0.801
#     sample_throughput: 745.72
#     sample_time_ms: 268.197
#     update_time_ms: 2.162
#   timestamp: 1639944975
#   timesteps_since_restore: 0
#   timesteps_total: 7600
#   training_iteration: 2
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     2</td><td style="text-align: right;">         16.3474</td><td style="text-align: right;">7600</td><td style="text-align: right;"> 77.7778</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           418.556</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     2</td><td style="text-align: right;">         16.3474</td><td style="text-align: right;">7600</td><td style="text-align: right;"> 77.7778</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           418.556</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 15000
#   custom_metrics: {}
#   date: 2021-12-19_15-16-26
#   done: false
#   episode_len_mean: 413.9189189189189
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 78.37837837837837
#   episode_reward_min: 60.0
#   episodes_this_iter: 19
#   episodes_total: 37
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 1.3600801257798723e-13
#           policy_loss: 0.0
#           var_gnorm: 10.909357070922852
#           vf_explained_var: 0.950473964214325
#           vf_loss: 2.428934097290039
#         train: null
#     num_agent_steps_sampled: 15000
#     num_agent_steps_trained: 15000
#     num_steps_sampled: 15000
#     num_steps_trained: 15000
#   iterations_since_restore: 3
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 32.128571428571426
#     ram_util_percent: 40.10000000000001
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05438321347579726
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7406369201264671
#     mean_inference_ms: 1.3437418190311692
#     mean_raw_obs_processing_ms: 0.19360154245953165
#   time_since_restore: 26.55130887031555
#   time_this_iter_s: 10.203927755355835
#   time_total_s: 26.55130887031555
#   timers:
#     learn_throughput: 14043.577
#     learn_time_ms: 14.241
#     load_throughput: 235555.655
#     load_time_ms: 0.849
#     sample_throughput: 705.592
#     sample_time_ms: 283.45
#     update_time_ms: 2.222
#   timestamp: 1639944986
#   timesteps_since_restore: 0
#   timesteps_total: 15000
#   training_iteration: 3
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     3</td><td style="text-align: right;">         26.5513</td><td style="text-align: right;">15000</td><td style="text-align: right;"> 78.3784</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           413.919</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     3</td><td style="text-align: right;">         26.5513</td><td style="text-align: right;">15000</td><td style="text-align: right;"> 78.3784</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           413.919</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 22400
#   custom_metrics: {}
#   date: 2021-12-19_15-16-36
#   done: false
#   episode_len_mean: 411.9107142857143
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 78.21428571428571
#   episode_reward_min: 60.0
#   episodes_this_iter: 19
#   episodes_total: 56
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 39.999996185302734
#           model: {}
#           policy_entropy: 4.1365723291164613e-07
#           policy_loss: 0.0
#           var_gnorm: 10.916982650756836
#           vf_explained_var: 0.9393056631088257
#           vf_loss: 3.932894229888916
#         train: null
#     num_agent_steps_sampled: 22400
#     num_agent_steps_trained: 22400
#     num_steps_sampled: 22400
#     num_steps_trained: 22400
#   iterations_since_restore: 4
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 30.786666666666658
#     ram_util_percent: 40.10000000000001
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.054336748657604024
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7409993266311351
#     mean_inference_ms: 1.34284248574131
#     mean_raw_obs_processing_ms: 0.19408150519703396
#   time_since_restore: 36.58492636680603
#   time_this_iter_s: 10.033617496490479
#   time_total_s: 36.58492636680603
#   timers:
#     learn_throughput: 14093.858
#     learn_time_ms: 14.191
#     load_throughput: 251653.207
#     load_time_ms: 0.795
#     sample_throughput: 738.95
#     sample_time_ms: 270.654
#     update_time_ms: 2.177
#   timestamp: 1639944996
#   timesteps_since_restore: 0
#   timesteps_total: 22400
#   training_iteration: 4
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.2/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     4</td><td style="text-align: right;">         36.5849</td><td style="text-align: right;">22400</td><td style="text-align: right;"> 78.2143</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.911</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     4</td><td style="text-align: right;">         36.5849</td><td style="text-align: right;">22400</td><td style="text-align: right;"> 78.2143</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.911</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 29600
#   custom_metrics: {}
#   date: 2021-12-19_15-16-46
#   done: false
#   episode_len_mean: 411.7105263157895
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 78.15789473684211
#   episode_reward_min: 60.0
#   episodes_this_iter: 20
#   episodes_total: 76
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 3.039107809854613e-07
#           policy_loss: 0.0
#           var_gnorm: 10.928171157836914
#           vf_explained_var: 0.9414781332015991
#           vf_loss: 3.740051507949829
#         train: null
#     num_agent_steps_sampled: 29600
#     num_agent_steps_trained: 29600
#     num_steps_sampled: 29600
#     num_steps_trained: 29600
#   iterations_since_restore: 5
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 35.34285714285715
#     ram_util_percent: 40.10000000000001
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05447733545085748
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.742838042635543
#     mean_inference_ms: 1.3454882804851285
#     mean_raw_obs_processing_ms: 0.19489395922519753
#   time_since_restore: 46.767037868499756
#   time_this_iter_s: 10.182111501693726
#   time_total_s: 46.767037868499756
#   timers:
#     learn_throughput: 14078.105
#     learn_time_ms: 14.206
#     load_throughput: 248448.288
#     load_time_ms: 0.805
#     sample_throughput: 721.74
#     sample_time_ms: 277.108
#     update_time_ms: 2.196
#   timestamp: 1639945006
#   timesteps_since_restore: 0
#   timesteps_total: 29600
#   training_iteration: 5
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     5</td><td style="text-align: right;">          46.767</td><td style="text-align: right;">29600</td><td style="text-align: right;"> 78.1579</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.711</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     5</td><td style="text-align: right;">          46.767</td><td style="text-align: right;">29600</td><td style="text-align: right;"> 78.1579</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.711</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 37000
#   custom_metrics: {}
#   date: 2021-12-19_15-16-56
#   done: false
#   episode_len_mean: 411.5851063829787
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 78.29787234042553
#   episode_reward_min: 60.0
#   episodes_this_iter: 18
#   episodes_total: 94
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 39.999996185302734
#           model: {}
#           policy_entropy: 0.0002073871874017641
#           policy_loss: -3.2757014878370683e-07
#           var_gnorm: 10.94045639038086
#           vf_explained_var: 0.9621171951293945
#           vf_loss: 2.0227980613708496
#         train: null
#     num_agent_steps_sampled: 37000
#     num_agent_steps_trained: 37000
#     num_steps_sampled: 37000
#     num_steps_trained: 37000
#   iterations_since_restore: 6
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 31.73333333333333
#     ram_util_percent: 40.10000000000001
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05453919200861718
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7435510125577229
#     mean_inference_ms: 1.346979019223738
#     mean_raw_obs_processing_ms: 0.1953218212533737
#   time_since_restore: 56.861438512802124
#   time_this_iter_s: 10.094400644302368
#   time_total_s: 56.861438512802124
#   timers:
#     learn_throughput: 14235.134
#     learn_time_ms: 14.05
#     load_throughput: 249423.406
#     load_time_ms: 0.802
#     sample_throughput: 748.608
#     sample_time_ms: 267.162
#     update_time_ms: 2.114
#   timestamp: 1639945016
#   timesteps_since_restore: 0
#   timesteps_total: 37000
#   training_iteration: 6
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     6</td><td style="text-align: right;">         56.8614</td><td style="text-align: right;">37000</td><td style="text-align: right;"> 78.2979</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.585</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     6</td><td style="text-align: right;">         56.8614</td><td style="text-align: right;">37000</td><td style="text-align: right;"> 78.2979</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           411.585</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 44400
#   custom_metrics: {}
#   date: 2021-12-19_15-17-06
#   done: false
#   episode_len_mean: 410.92
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 78.4
#   episode_reward_min: 70.0
#   episodes_this_iter: 19
#   episodes_total: 113
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 43.50033950805664
#           policy_loss: -2.8569767475128174
#           var_gnorm: 10.95610523223877
#           vf_explained_var: 0.7752901315689087
#           vf_loss: 3.6883392333984375
#         train: null
#     num_agent_steps_sampled: 44400
#     num_agent_steps_trained: 44400
#     num_steps_sampled: 44400
#     num_steps_trained: 44400
#   iterations_since_restore: 7
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 34.55
#     ram_util_percent: 40.17857142857143
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05462717302760179
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7450571061835931
#     mean_inference_ms: 1.349771986686371
#     mean_raw_obs_processing_ms: 0.19608186723948998
#   time_since_restore: 67.08733034133911
#   time_this_iter_s: 10.225891828536987
#   time_total_s: 67.08733034133911
#   timers:
#     learn_throughput: 13705.375
#     learn_time_ms: 14.593
#     load_throughput: 224751.045
#     load_time_ms: 0.89
#     sample_throughput: 689.744
#     sample_time_ms: 289.963
#     update_time_ms: 2.828
#   timestamp: 1639945026
#   timesteps_since_restore: 0
#   timesteps_total: 44400
#   training_iteration: 7
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     7</td><td style="text-align: right;">         67.0873</td><td style="text-align: right;">44400</td><td style="text-align: right;">    78.4</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  70</td><td style="text-align: right;">            410.92</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     7</td><td style="text-align: right;">         67.0873</td><td style="text-align: right;">44400</td><td style="text-align: right;">    78.4</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  70</td><td style="text-align: right;">            410.92</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 52200
#   custom_metrics: {}
#   date: 2021-12-19_15-17-16
#   done: false
#   episode_len_mean: 437.27
#   episode_media: {}
#   episode_reward_max: 80.0
#   episode_reward_mean: 77.3
#   episode_reward_min: 20.0
#   episodes_this_iter: 2
#   episodes_total: 115
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 39.999996185302734
#           model: {}
#           policy_entropy: 282.56927490234375
#           policy_loss: 18.794845581054688
#           var_gnorm: 10.996954917907715
#           vf_explained_var: -0.007247328758239746
#           vf_loss: 6.31093168258667
#         train: null
#     num_agent_steps_sampled: 52200
#     num_agent_steps_trained: 52200
#     num_steps_sampled: 52200
#     num_steps_trained: 52200
#   iterations_since_restore: 8
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 32.38
#     ram_util_percent: 40.39999999999999
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05465458121406394
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7452727365918076
#     mean_inference_ms: 1.3499366316608787
#     mean_raw_obs_processing_ms: 0.19600308221670676
#   time_since_restore: 77.2934148311615
#   time_this_iter_s: 10.206084489822388
#   time_total_s: 77.2934148311615
#   timers:
#     learn_throughput: 13991.74
#     learn_time_ms: 14.294
#     load_throughput: 239619.744
#     load_time_ms: 0.835
#     sample_throughput: 765.337
#     sample_time_ms: 261.323
#     update_time_ms: 2.292
#   timestamp: 1639945036
#   timesteps_since_restore: 0
#   timesteps_total: 52200
#   training_iteration: 8
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     8</td><td style="text-align: right;">         77.2934</td><td style="text-align: right;">52200</td><td style="text-align: right;">    77.3</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  20</td><td style="text-align: right;">            437.27</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     8</td><td style="text-align: right;">         77.2934</td><td style="text-align: right;">52200</td><td style="text-align: right;">    77.3</td><td style="text-align: right;">                  80</td><td style="text-align: right;">                  20</td><td style="text-align: right;">            437.27</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 59800
#   custom_metrics: {}
#   date: 2021-12-19_15-17-27
#   done: false
#   episode_len_mean: 450.48
#   episode_media: {}
#   episode_reward_max: 170.0
#   episode_reward_mean: 75.3
#   episode_reward_min: 0.0
#   episodes_this_iter: 7
#   episodes_total: 122
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.000003814697266
#           model: {}
#           policy_entropy: 438.7979736328125
#           policy_loss: -8.923070907592773
#           var_gnorm: 11.020637512207031
#           vf_explained_var: 0.0009496808052062988
#           vf_loss: 0.43639248609542847
#         train: null
#     num_agent_steps_sampled: 59800
#     num_agent_steps_trained: 59800
#     num_steps_sampled: 59800
#     num_steps_trained: 59800
#   iterations_since_restore: 9
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 31.628571428571426
#     ram_util_percent: 40.39999999999999
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.054698188440959396
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.745557293991281
#     mean_inference_ms: 1.350145858167105
#     mean_raw_obs_processing_ms: 0.19576300328981527
#   time_since_restore: 87.32903814315796
#   time_this_iter_s: 10.03562331199646
#   time_total_s: 87.32903814315796
#   timers:
#     learn_throughput: 14184.37
#     learn_time_ms: 14.1
#     load_throughput: 245352.676
#     load_time_ms: 0.815
#     sample_throughput: 755.036
#     sample_time_ms: 264.888
#     update_time_ms: 2.123
#   timestamp: 1639945047
#   timesteps_since_restore: 0
#   timesteps_total: 59800
#   training_iteration: 9
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     9</td><td style="text-align: right;">          87.329</td><td style="text-align: right;">59800</td><td style="text-align: right;">    75.3</td><td style="text-align: right;">                 170</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            450.48</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">     9</td><td style="text-align: right;">          87.329</td><td style="text-align: right;">59800</td><td style="text-align: right;">    75.3</td><td style="text-align: right;">                 170</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            450.48</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 67400
#   custom_metrics: {}
#   date: 2021-12-19_15-17-37
#   done: false
#   episode_len_mean: 557.85
#   episode_media: {}
#   episode_reward_max: 170.0
#   episode_reward_mean: 74.2
#   episode_reward_min: 0.0
#   episodes_this_iter: 12
#   episodes_total: 134
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 450.1761779785156
#           policy_loss: 36.37498092651367
#           var_gnorm: 11.03261661529541
#           vf_explained_var: 0.23192012310028076
#           vf_loss: 14.260164260864258
#         train: null
#     num_agent_steps_sampled: 67400
#     num_agent_steps_trained: 67400
#     num_steps_sampled: 67400
#     num_steps_trained: 67400
#   iterations_since_restore: 10
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 31.373333333333335
#     ram_util_percent: 40.39999999999999
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05472297781359167
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.7456333027779907
#     mean_inference_ms: 1.3500604201033355
#     mean_raw_obs_processing_ms: 0.19480027705373967
#   time_since_restore: 97.45999884605408
#   time_this_iter_s: 10.130960702896118
#   time_total_s: 97.45999884605408
#   timers:
#     learn_throughput: 14154.93
#     learn_time_ms: 14.129
#     load_throughput: 241294.635
#     load_time_ms: 0.829
#     sample_throughput: 750.507
#     sample_time_ms: 266.487
#     update_time_ms: 2.16
#   timestamp: 1639945057
#   timesteps_since_restore: 0
#   timesteps_total: 67400
#   training_iteration: 10
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">    10</td><td style="text-align: right;">           97.46</td><td style="text-align: right;">67400</td><td style="text-align: right;">    74.2</td><td style="text-align: right;">                 170</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            557.85</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.3/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">    10</td><td style="text-align: right;">           97.46</td><td style="text-align: right;">67400</td><td style="text-align: right;">    74.2</td><td style="text-align: right;">                 170</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            557.85</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 75000
#   custom_metrics: {}
#   date: 2021-12-19_15-17-47
#   done: false
#   episode_len_mean: 584.35
#   episode_media: {}
#   episode_reward_max: 170.0
#   episode_reward_mean: 73.6
#   episode_reward_min: 0.0
#   episodes_this_iter: 13
#   episodes_total: 147
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 40.0
#           model: {}
#           policy_entropy: 507.8266906738281
#           policy_loss: 30.685760498046875
#           var_gnorm: 11.037708282470703
#           vf_explained_var: -0.09832370281219482
#           vf_loss: 14.20486068725586
#         train: null
#     num_agent_steps_sampled: 75000
#     num_agent_steps_trained: 75000
#     num_steps_sampled: 75000
#     num_steps_trained: 75000
#   iterations_since_restore: 11
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 31.228571428571428
#     ram_util_percent: 40.39999999999999
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05471566394209105
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.745757413425597
#     mean_inference_ms: 1.350284286955798
#     mean_raw_obs_processing_ms: 0.19338175733833957
#   time_since_restore: 107.5627748966217
#   time_this_iter_s: 10.102776050567627
#   time_total_s: 107.5627748966217
#   timers:
#     learn_throughput: 14131.276
#     learn_time_ms: 14.153
#     load_throughput: 239633.434
#     load_time_ms: 0.835
#     sample_throughput: 759.544
#     sample_time_ms: 263.316
#     update_time_ms: 2.76
#   timestamp: 1639945067
#   timesteps_since_restore: 0
#   timesteps_total: 75000
#   training_iteration: 11
# ...
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 6.4/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">    49</td><td style="text-align: right;">         492.909</td><td style="text-align: right;">360800</td><td style="text-align: right;">     121</td><td style="text-align: right;">                 240</td><td style="text-align: right;">                  10</td><td style="text-align: right;">            578.46</td></tr>
# </tbody>
# </table><br><br>
# Result for A2C_Frostbite-v0_74b39_00000:
#   agent_timesteps_total: 368400
#   custom_metrics: {}
#   date: 2021-12-19_15-24-23
#   done: false
#   episode_len_mean: 580.52
#   episode_media: {}
#   episode_reward_max: 260.0
#   episode_reward_mean: 134.6
#   episode_reward_min: 10.0
#   episodes_this_iter: 13
#   episodes_total: 689
#   experiment_id: 2db2de95f09d4a8582be21836ec1643a
#   hostname: ml2558-G11CD
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 9.999999747378752e-05
#           grad_gnorm: 39.999996185302734
#           model: {}
#           policy_entropy: 474.266357421875
#           policy_loss: 148.001708984375
#           var_gnorm: 11.187053680419922
#           vf_explained_var: 0.5603840351104736
#           vf_loss: 39.65641403198242
#         train: null
#     num_agent_steps_sampled: 368400
#     num_agent_steps_trained: 368400
#     num_steps_sampled: 368400
#     num_steps_trained: 368400
#   iterations_since_restore: 50
#   node_ip: 132.236.59.202
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 31.81428571428571
#     ram_util_percent: 41.10000000000001
#   pid: 2409
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05418516048673602
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.742836964910721
#     mean_inference_ms: 1.341040881789009
#     mean_raw_obs_processing_ms: 0.18104367829843526
#   time_since_restore: 503.15428137779236
#   time_this_iter_s: 10.245137691497803
#   time_total_s: 503.15428137779236
#   timers:
#     learn_throughput: 14142.831
#     learn_time_ms: 14.141
#     load_throughput: 251547.559
#     load_time_ms: 0.795
#     sample_throughput: 748.501
#     sample_time_ms: 267.201
#     update_time_ms: 2.123
#   timestamp: 1639945463
#   timesteps_since_restore: 0
#   timesteps_total: 368400
#   training_iteration: 50
#   trial_id: 74b39_00000
# == Status ==<br>Memory usage on this node: 6.4/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">    50</td><td style="text-align: right;">         503.154</td><td style="text-align: right;">368400</td><td style="text-align: right;">   134.6</td><td style="text-align: right;">                 260</td><td style="text-align: right;">                  10</td><td style="text-align: right;">            580.52</td></tr>
# </tbody>
# </table><br><br>
# 2021-12-19 15:24:31,506	WARNING tune.py:574 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# == Status ==<br>Memory usage on this node: 6.4/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 1.0/1 GPUs, 0.0/7.43 GiB heap, 0.0/3.72 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /home/ml2558/ray_results/A2C_2021-12-19_15-15-48<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                  </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>A2C_Frostbite-v0_74b39_00000</td><td>RUNNING </td><td>132.236.59.202:2409</td><td style="text-align: right;">    50</td><td style="text-align: right;">         503.154</td><td style="text-align: right;">368400</td><td style="text-align: right;">   134.6</td><td style="text-align: right;">                 260</td><td style="text-align: right;">                  10</td><td style="text-align: right;">            580.52</td></tr>
# </tbody>
# </table><br><br>
# (pid=2444) 2021-12-19 15:24:31,519	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=2444) Traceback (most recent call last):
# (pid=2444)   File "python/ray/_raylet.pyx", line 684, in ray._raylet.task_execution_handler
# (pid=2444)   File "python/ray/_raylet.pyx", line 524, in ray._raylet.execute_task
# (pid=2444)   File "python/ray/_raylet.pyx", line 561, in ray._raylet.execute_task
# (pid=2444)   File "python/ray/_raylet.pyx", line 568, in ray._raylet.execute_task
# (pid=2444)   File "python/ray/_raylet.pyx", line 572, in ray._raylet.execute_task
# (pid=2444)   File "python/ray/_raylet.pyx", line 522, in ray._raylet.execute_task.function_executor
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/_private/function_manager.py", line 579, in actor_method_executor
# (pid=2444)     return method(__ray_actor, *args, **kwargs)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 449, in _resume_span
# (pid=2444)     return method(self, *_args, **_kwargs)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/iter.py", line 1151, in par_iter_next
# (pid=2444)     return next(self.local_it)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/rollout_worker.py", line 377, in gen_rollouts
# (pid=2444)     yield self.sample()
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 449, in _resume_span
# (pid=2444)     return method(self, *_args, **_kwargs)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/rollout_worker.py", line 752, in sample
# (pid=2444)     batches = [self.input_reader.next()]
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 103, in next
# (pid=2444)     batches = [self.get_data()]
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 233, in get_data
# (pid=2444)     item = next(self._env_runner)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 622, in _env_runner
# (pid=2444)     eval_results = _do_policy_eval(
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 1035, in _do_policy_eval
# (pid=2444)     policy.compute_actions_from_input_dict(
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/policy/tf_policy.py", line 463, in compute_actions_from_input_dict
# (pid=2444)     fetched = builder.get(to_fetch)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/utils/tf_run_builder.py", line 42, in get
# (pid=2444)     self._executed = run_timeline(
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/utils/tf_run_builder.py", line 89, in run_timeline
# (pid=2444)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 967, in run
# (pid=2444)     result = self._run(None, fetches, feed_dict, options_ptr,
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1190, in _run
# (pid=2444)     results = self._do_run(handle, final_targets, final_fetches,
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1368, in _do_run
# (pid=2444)     return self._do_call(_run_fn, feeds, fetches, targets, options,
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1375, in _do_call
# (pid=2444)     return fn(*args)
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1359, in _run_fn
# (pid=2444)     return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1451, in _call_tf_sessionrun
# (pid=2444)     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
# (pid=2444)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=2444)     sys.exit(1)
# (pid=2444) SystemExit: 1
# (pid=2443) 2021-12-19 15:24:31,519	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=2443) Traceback (most recent call last):
# (pid=2443)   File "python/ray/_raylet.pyx", line 684, in ray._raylet.task_execution_handler
# (pid=2443)   File "python/ray/_raylet.pyx", line 524, in ray._raylet.execute_task
# (pid=2443)   File "python/ray/_raylet.pyx", line 561, in ray._raylet.execute_task
# (pid=2443)   File "python/ray/_raylet.pyx", line 568, in ray._raylet.execute_task
# (pid=2443)   File "python/ray/_raylet.pyx", line 572, in ray._raylet.execute_task
# (pid=2443)   File "python/ray/_raylet.pyx", line 522, in ray._raylet.execute_task.function_executor
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/_private/function_manager.py", line 579, in actor_method_executor
# (pid=2443)     return method(__ray_actor, *args, **kwargs)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 449, in _resume_span
# (pid=2443)     return method(self, *_args, **_kwargs)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/iter.py", line 1151, in par_iter_next
# (pid=2443)     return next(self.local_it)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/rollout_worker.py", line 377, in gen_rollouts
# (pid=2443)     yield self.sample()
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 449, in _resume_span
# (pid=2443)     return method(self, *_args, **_kwargs)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/rollout_worker.py", line 752, in sample
# (pid=2443)     batches = [self.input_reader.next()]
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 103, in next
# (pid=2443)     batches = [self.get_data()]
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 233, in get_data
# (pid=2443)     item = next(self._env_runner)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 622, in _env_runner
# (pid=2443)     eval_results = _do_policy_eval(
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/evaluation/sampler.py", line 1035, in _do_policy_eval
# (pid=2443)     policy.compute_actions_from_input_dict(
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/policy/tf_policy.py", line 463, in compute_actions_from_input_dict
# (pid=2443)     fetched = builder.get(to_fetch)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/utils/tf_run_builder.py", line 42, in get
# (pid=2443)     self._executed = run_timeline(
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/rllib/utils/tf_run_builder.py", line 89, in run_timeline
# (pid=2443)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 967, in run
# (pid=2443)     result = self._run(None, fetches, feed_dict, options_ptr,
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1190, in _run
# (pid=2443)     results = self._do_run(handle, final_targets, final_fetches,
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1368, in _do_run
# (pid=2443)     return self._do_call(_run_fn, feeds, fetches, targets, options,
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1375, in _do_call
# (pid=2443)     return fn(*args)
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1359, in _run_fn
# (pid=2443)     return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1451, in _call_tf_sessionrun
# (pid=2443)     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
# (pid=2443)   File "/home/ml2558/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=2443)     sys.exit(1)
# (pid=2443) SystemExit: 1
# 2021-12-19 15:24:31,720	ERROR tune.py:613 -- Trials did not complete: [A2C_Frostbite-v0_74b39_00000]
# 2021-12-19 15:24:31,721	INFO tune.py:617 -- Total run time: 523.03 seconds (522.78 seconds for the tuning loop).
# 2021-12-19 15:24:31,721	WARNING tune.py:621 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
